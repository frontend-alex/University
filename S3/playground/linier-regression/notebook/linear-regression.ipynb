# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(40)

hours = 2 * np.random.rand(100, 11)

scores = 5 * hours + np.random.randn(100, 1)


plt.scatter(hours, scores)
plt.xlabel('Hours Studied')
plt.ylabel('Test Scores')
plt.title('Training Data')
plt.show()
# Out:
# [[4.07687028 0.5536604  7.88534877 ... 7.76775458 6.86241645 9.80938863]
#  [6.00816092 8.1396852  7.08645152 ... 2.02248226 1.74202671 4.4914708 ]
#  [6.69794781 9.57399109 8.33333251 ... 6.36922242 3.62295894 0.14574549]
#  ...
#  [6.38375698 4.55060152 3.39726261 ... 8.16790117 7.80237388 5.70733018]
#  [0.56841099 5.73262992 5.67199632 ... 3.63975833 2.30368768 3.18697153]
#  [8.45374594 4.2624508  6.96955523 ... 0.55076947 9.3141651  5.5895574 ]]
# [[20.09010521  2.47405582 39.13249768 ... 38.5445267  34.01783608
#   48.75269697]
#  [30.20930797 40.86692935 35.60076096 ... 10.28091467  8.87863688
#   22.62585734]
#  [34.23429983 48.61451625 42.41122334 ... 32.59067292 18.8593555
#    1.47328827]
#  ...
#  [32.01881441 22.85303714 17.08634256 ... 40.93953535 39.11189892
#   28.63668043]
#  [ 3.55573232 29.37682698 29.07365898 ... 18.91246904 12.23211582
#   16.64853505]
#  [42.62167524 21.66519955 35.20072167 ...  3.10679289 46.92377102
#   28.30073251]]
