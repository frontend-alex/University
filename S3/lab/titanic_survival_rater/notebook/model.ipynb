# %% [markdown]
# # Titanic Survival Rater
# Decision Tree classifier to predict Titanic passenger survival.

# %% [markdown]
# ## 1 · Load & Preprocess

# %%
from src.data import load_raw, preprocess

df = load_raw()
df = preprocess(df, save=True)
df.head()

# %% [markdown]
# ## 2 · Train Model

# %%
from src.models import train_model

model, X_train, X_test, y_train, y_test = train_model(df=df)
print(f"Train: {len(X_train)}, Test: {len(X_test)}")

# %% [markdown]
# ## 3 · Single Passenger Prediction

# %%
from src.models import predict_survival

result = predict_survival(pclass=1, sex=1, cherbourg=0, model=model)
print("Survived" if result else "Did not survive")
