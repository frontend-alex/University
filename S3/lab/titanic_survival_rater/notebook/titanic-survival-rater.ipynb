# %%
from src.data import load_raw, preprocess
df = load_raw()
df = preprocess(df, save=True)
df.head()
# Out:
#    pclass  sex      age  Cherbourg  Queenstown  Southampton  survived
# 0       1    1  29.0000      False       False         True         1
# 1       1    1   2.0000      False       False         True         0
# 2       1    0  30.0000      False       False         True         0
# 3       1    1  25.0000      False       False         True         0
# 4       1    0   0.9167      False       False         True         1

# %%
from src.models import train_model, predict_survival
model, X_train, X_test, y_train, y_test = train_model(df=df)
print(f"Train: {len(X_train)}, Test: {len(X_test)}")
# Out:
# Train: 1050, Test: 263

# %%
result = predict_survival(pclass=1, sex=0, cherbourg=1)
print("Survived" if result else "Did not survive")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = predict_survival(pclass=1, sex=0, cherbourg=1)
#       2 print("Survived" if result else "Did not survive")
#
# NameError: name 'predict_survival' is not defined
